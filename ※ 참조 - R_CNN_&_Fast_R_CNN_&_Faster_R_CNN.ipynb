# %% [markdown]
# <a href="https://colab.research.google.com/github/falling90/RCNN/blob/main/2_R_CNN_%26_Fast_R_CNN_%26_Faster_R_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * 출처
#  1) https://www.youtube.com/watch?v=vr5rs_cTKCs&t=353s

# %% [markdown]
# # <strong>1. R-CNN</strong>
# 　-. CNN 네트워크가 고정된 크기로 사용하여야 하므로
#  　　자르거나 크기를 조정해야 하는 작업이 필요하고, 이로 인해 잃어버리는 데이터가 많다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <strong>2. Fast R-CNN</strong>
# 　-. ROI 투영 (Projection) : 한번에 Convolutional Layer로 전달되는 입력 이미지를 가지고있다.
# 　-. Feature Map : 선택적 검색

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <strong>3. Faster R-CNN</strong>
# 　-. Feature Map : RPN (Region Proposal Network)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
